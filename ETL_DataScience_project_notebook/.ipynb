# %%
import pandas as pd
#import psycopg2 as ps
from sqlalchemy import create_engine

# %%
csv_file_all_data = "../Resources/alldata.csv"
DS_jobs_all_data_df = pd.read_csv(csv_file_all_data)
DS_jobs_all_data_df.head(10)
# Out:
#                                             position             company  \
# 0                               Development Director             ALS TDI
# 1  An Ostentatiously-Excitable Principal Research...  The Hexagon Lavish
# 2                                     Data Scientist      Xpert Staffing
# 3                                       Data Analyst      Operation HOPE
# 4  Assistant Professor -TT - Signal Processing & ...    Emory University
# 5                        Manager of Data Engineering  McKinsey & Company
# 6       Product Specialist - Periscope, New Ventures  McKinsey & Company
# 7  Junior to Mid-level Engineer, Geologist or Env...                Wood
# 8                      Analyst - CIB Credit Research            SunTrust
# 9  Senior Associate - Cognitive Data Scientist Na...                KPMG
#
#                                          description  reviews  \
# 0  Development Director\nALS Therapy Development ...      NaN
# ...

# %%
#Create new data with selected columns- position, company, description, number of review, location
new_DS_jobs_all_data_df = DS_jobs_all_data_df[["position", "company","description","location"]].copy()
new_DS_jobs_all_data_df.head()
# Out:
#                                             position             company  \
# 0                               Development Director             ALS TDI
# 1  An Ostentatiously-Excitable Principal Research...  The Hexagon Lavish
# 2                                     Data Scientist      Xpert Staffing
# 3                                       Data Analyst      Operation HOPE
# 4  Assistant Professor -TT - Signal Processing & ...    Emory University
#
#                                          description            location
# 0  Development Director\nALS Therapy Development ...  Atlanta, GA 30301
# 1  Job Description\n\n"The road that leads to acc...         Atlanta, GA
# 2  Growing company located in the Atlanta, GA are...         Atlanta, GA
# 3  DEPARTMENT: Program OperationsPOSITION LOCATIO...  Atlanta, GA 30303
# 4  DESCRIPTION\nThe Emory University Department o...         Atlanta, GA

# %%
#Create new data with selected columns- position, company, description, number of review, location
new_DS_jobs_Austin_TX_df = DS_jobs_Austin_TX_df[["position", "company","location"]].copy()
new_DS_jobs_Austin_TX_df.head()
# Out:
#                                             position  \
# 0                      Senior Scientist, Development
# 1                             Data Software Engineer
# 2                           Bioinformatics Scientist
# 3  Research Engineering/ Scientist Associate II -...
# 4                                Lead Data Scientist
#
#                          company          location
# 0                       Asuragen        Austin, TX
# 1                         Kelvin        Austin, TX
# 2                   Premierehire        Austin, TX
# 3  University of Texas at Austin        Austin, TX
# 4            Clockwork Solutions  Austin, TX 78746

# %%
#Connect to a local database
rds_connection_string = "<insert user name>:<insert password>@localhost:5432/customer_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
 engine.table_names()
